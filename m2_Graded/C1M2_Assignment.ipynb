# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Write a complete, well-structured draft essay about the following topic: {topic}. 
    Ensure the essay includes a clear introduction, detailed body paragraphs, 
    and a cohesive conclusion.
    """
    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Please provide a critical yet constructive reflection on the following essay draft:
    
    {draft}
    
    Focus your feedback on the overall structure, clarity of the message, 
    the strength of the arguments, and the general writing style. 
    Provide
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Original Draft:
    {original_draft}
    
    Feedback for Improvement:
    {reflection}
    
    Based on the feedback above, rewrite the essay to improve its clarity, 
    coherence, and argument strength. Return only the final revised essay.
    """ 

    # Get a response from the LLM by creating a chat with the client.
    response =  CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction
#
# In the contemporary digital age, social media platforms have woven themselves into the fabric of daily life, influencing how individuals communicate, acquire information, and engage with society. These platforms hold immense power, shaping public opinion, affecting elections, and even inciting real-world actions. Given their significant impact, a pertinent question arises: should social media platforms be regulated by the government? This essay explores this issue, arguing that government regulation is essential to ensure accountability, protect users' rights, and preserve democratic processes.
#
# The Need for Accountability
#
# The sheer scale and influence of social media platforms necessitate a framework that holds them accountable for their operations. Companies like Facebook, Twitter, and Instagram have become powerful entities, often operating with minimal oversight. Without regulation, these platforms prioritize profits over users’ welfare, failing to adequately address issues like misinformation, harmful content, and data privacy violations. Government regulation would ensure that these companies adhere to ethical standards, promoting transparency and accountability in their practices. Clear guidelines and oversight mechanisms would oblige social media platforms to prioritize user safety and societal well-being, fostering a healthier digital environment.
#
# Protecting Users' Rights
#
# In the digital realm, users' rights, including privacy and freedom of expression, are frequently compromised. Social media platforms often exploit personal data for commercial gain, with little regard for individuals' privacy concerns. Moreover, the algorithms guiding much of social media interaction can inadvertently stifle freedom of expression by promoting echo chambers and censoring diverse viewpoints. By enacting comprehensive regulations, governments can protect users' rights, ensuring that privacy is safeguarded and free speech is balanced with the need to prevent harm. Regulations can mandate transparent data policies and enable users to have greater control over their online presence, curbing the misuse of personal information.
#
# Preserving Democratic Processes
#
# Social media has undeniably influenced political landscapes worldwide, for better or worse. While these platforms provide a voice to marginalized groups, they also serve as conduits for misinformation, fake news, and political manipulation. The unchecked spread of false information can undermine democratic processes, swaying public opinion and altering elections' outcomes. Government regulation is crucial in setting standards that mitigate these risks, such as implementing robust fact-checking initiatives and preventing foreign interference. By establishing a framework of oversight, governments can ensure that social media platforms act responsibly, contributing to informed, fair, and democratic political processes.
#
# Opposition to Regulation
#
# Critics of government regulation argue that it could impede innovation and infringe on freedom of speech. They caution against excessive control, which might lead to censorship and stifle creative expression. However, it is essential to differentiate between responsible regulation and authoritarian control. Thoughtfully crafted regulations can strike a balance between protecting rights and allowing innovation to flourish. Moreover, regulation does not mean censorship; rather, it provides a structure within which free speech can operate without harm. The goal is not to stifle dialogue but to create a safe and equitable digital environment for all users.
#
# Conclusion
#
# As social media platforms continue to entwine themselves with societal functions, the call for government regulation becomes increasingly urgent. Regulation is not about stifling innovation or limiting free speech; it is about fostering accountability, protecting individual rights, and preserving democratic integrity. By implementing sensible regulations, governments can guide social media platforms towards responsible operation, ensuring they serve as tools that enhance, rather than harm, societal progress. The digital frontier is vast and ever-evolving, but with thoughtful oversight, it can be navigated to benefit both individuals and the collective global community.
#
# 🧠 Feedback:
#
# Here’s a balanced, constructive look at your draft, organized around structure, clarity, argument strength, and style:
#
# 1. Structure
# • Clear sectional layout: You’ve neatly divided the essay into an introduction, three main arguments, opposition, and conclusion. This makes it easy to follow.
# • Transitional flow: At times the jump from one section to the next feels abrupt. Consider brief transitional sentences (“Building on the need for accountability…,” “Equally important is how regulation affects democratic processes…”) to guide the reader.
# • Depth of development: Each section introduces a solid thesis, but some could benefit from subpoints or mini-headings (e.g., under “Protecting Users’ Rights,” you might have sub-sections on privacy and on free-speech concerns).
#
# 2. Clarity of Message
# • Strong central claim: Your thesis—that government regulation is both necessary and compatible with free expression—comes through clearly.
# • Precision and specificity: Phrases like “immense power” or “significant impact” are evocative, but concrete examples (a particular misinformation campaign, data-breach statistics, or a court ruling) would anchor your claims.
# • Avoiding generalities: When you say platforms “fail to adequately address harmful content,” you might specify the type of content or cite a study on moderation backlogs to sharpen the point.
#
# 3. Strength of Arguments
# • Accountability: The call for “ethical standards” is persuasive. To reinforce it, you could cite existing regulatory proposals (e.g., the EU’s Digital Services Act) or outcomes from self-regulatory bodies.
# • Users’ Rights: You rightly highlight privacy and algorithmic bias. Adding a brief case study—say, Cambridge Analytica for data misuse or a documented algorithmic amplification of extremist content—would make this more convincing.
# • Democratic Processes: Good identification of misinformation and foreign interference. You could strengthen it by noting specific electoral events where social media played a documented role (e.g., 2016 U.S. election, Brexit referendum).
# • Handling objections: You acknowledge concerns about innovation and censorship, and you distinguish “responsible regulation” from “authoritarian control.” You might anticipate a secondary objection—how to enforce standards internationally when platforms are global—and briefly suggest coordination mechanisms (multilateral treaties, cross-border regulatory bodies).
#
# 4. Writing Style
# • Tone: Your language is formal and balanced, suitable for a policy-oriented essay.
# • Sentence variety: Most sentences are similarly structured (intro phrase + claim + rationale). Introducing shorter, punchier sentences in key places (e.g., the thesis statement or conclusion) can increase impact.
# • Word choice: Watch for repetition (“regulation,” “platforms,” “government”)—vary with synonyms like “oversight,” “services,” or “public authorities” where appropriate.
# • Conciseness: A few sentences could be tightened. For instance, “Given their significant impact, a pertinent question arises: should social media platforms be regulated by the government?” could be shortened to “Given their impact on society, should governments regulate social media?”
#
# 5. Suggestions for Revision
# • Add concrete examples or data points in each main section to support your claims.
# • Smooth transitions between sections to improve the essay’s narrative flow.
# • Deepen the counterargument section by addressing enforcement challenges and international coordination.
# • Vary sentence length and structure to maintain reader engagement and emphasize key ideas.
# • Trim redundant phrases to sharpen your prose.
#
# Overall, your draft lays a solid foundation: you have a clear thesis, logical structure, and a fair engagement with opposing views. By grounding your arguments in specific examples, refining transitions, and tightening your style, you’ll move from a persuasive outline to a truly compelling essay.
# ✍️ Revised:
#
# Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction
#
# In today’s digital age, social media platforms have become integral to daily life, influencing how people communicate, acquire information, and engage with society. These platforms wield significant power, shaping public opinion, influencing elections, and sometimes sparking real-world actions. This influence raises an essential question: should governments regulate social media platforms? This essay argues that such regulation is necessary to ensure accountability, protect users' rights, and preserve democratic processes.
#
# The Need for Accountability
#
# Social media platforms like Facebook, Twitter, and Instagram have grown into powerful entities with substantial influence. Operating with minimal oversight, they often prioritize profits over users’ welfare, neglecting issues like misinformation, harmful content, and data privacy violations. Government regulation is essential to ensure these companies adhere to ethical standards. For instance, the European Union’s Digital Services Act provides a framework for transparency and accountability, obliging social media platforms to prioritize user safety and societal well-being. By mandating clear guidelines and oversight, governments can create a healthier digital environment.
#
# Protecting Users' Rights
#
# In the digital sphere, users' rights, including privacy and freedom of expression, are frequently compromised. Social media platforms commercialize personal data, often disregarding users' privacy concerns. Furthermore, their algorithms can inadvertently promote echo chambers and censor diverse viewpoints. Through comprehensive regulation, governments can protect these rights. The Cambridge Analytica scandal vividly illustrates the misuse of personal data, highlighting the need for robust data protection policies. By mandating transparency and empowering users with greater control over their online presence, regulations can balance privacy with free speech while preventing harm.
#
# Preserving Democratic Processes
#
# Social media’s role in political landscapes worldwide cannot be ignored. While these platforms provide a voice for marginalized groups, they also spread misinformation, fake news, and enable political manipulation. The unchecked dissemination of false information can undermine democratic processes and influence election outcomes. Government regulation is crucial in setting standards to mitigate these risks. For example, the spread of misinformation during the 2016 U.S. election underscores the need for robust fact-checking and measures to prevent foreign interference. By establishing oversight frameworks, governments can ensure that social media platforms act responsibly, contributing to informed and democratic political processes.
#
# Opposition to Regulation
#
# Critics argue that regulation could stifle innovation and infringe on free speech. However, it is vital to distinguish between responsible regulation and authoritarian control. Thoughtfully crafted regulations can balance protecting rights with fostering innovation. Regulation does not equate to censorship; instead, it provides a structure within which free speech can thrive without harm. Addressing another potential objection, international coordination is necessary since social media platforms operate globally. Multilateral treaties or cross-border regulatory bodies could help enforce standards internationally.
#
# Conclusion
#
# As social media platforms continue to intertwine with societal functions, the call for government regulation becomes increasingly urgent. Regulation is not about stifling innovation or limiting free speech; it is about fostering accountability, protecting individual rights, and preserving democratic integrity. By implementing sensible regulations, governments can guide social media towards responsible operation, ensuring these platforms bolster rather than hinder societal progress. The digital frontier is vast and ever-evolving, but with thoughtful oversight, it can be navigated to benefit individuals and the global community alike.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction
#
# In the contemporary digital age, social media platforms have woven themselves into the fabric of daily life, influencing how individuals communicate, acquire information, and engage with society. These platforms hold immense power, shaping public opinion, affecting elections, and even inciting real-world actions. Given their significant impact, a pertinent question arises: should social media platforms be regulated by the government? This essay explores this issue, arguing that government regulation is essential to ensure accountability, protect users' rights, and preserve democratic processes.
#
# The Need for Accountability
#
# The sheer scale and influence of social media platforms necessitate a framework that holds them accountable for their operations. Companies like Facebook, Twitter, and Instagram have become powerful entities, often operating with minimal oversight. Without regulation, these platforms prioritize profits over users’ welfare, failing to adequately address issues like misinformation, harmful content, and data privacy violations. Government regulation would ensure that these companies adhere to ethical standards, promoting transparency and accountability in their practices. Clear guidelines and oversight mechanisms would oblige social media platforms to prioritize user safety and societal well-being, fostering a healthier digital environment.
#
# Protecting Users' Rights
#
# In the digital realm, users' rights, including privacy and freedom of expression, are frequently compromised. Social media platforms often exploit personal data for commercial gain, with little regard for individuals' privacy concerns. Moreover, the algorithms guiding much of social media interaction can inadvertently stifle freedom of expression by promoting echo chambers and censoring diverse viewpoints. By enacting comprehensive regulations, governments can protect users' rights, ensuring that privacy is safeguarded and free speech is balanced with the need to prevent harm. Regulations can mandate transparent data policies and enable users to have greater control over their online presence, curbing the misuse of personal information.
#
# Preserving Democratic Processes
#
# Social media has undeniably influenced political landscapes worldwide, for better or worse. While these platforms provide a voice to marginalized groups, they also serve as conduits for misinformation, fake news, and political manipulation. The unchecked spread of false information can undermine democratic processes, swaying public opinion and altering elections' outcomes. Government regulation is crucial in setting standards that mitigate these risks, such as implementing robust fact-checking initiatives and preventing foreign interference. By establishing a framework of oversight, governments can ensure that social media platforms act responsibly, contributing to informed, fair, and democratic political processes.
#
# Opposition to Regulation
#
# Critics of government regulation argue that it could impede innovation and infringe on freedom of speech. They caution against excessive control, which might lead to censorship and stifle creative expression. However, it is essential to differentiate between responsible regulation and authoritarian control. Thoughtfully crafted regulations can strike a balance between protecting rights and allowing innovation to flourish. Moreover, regulation does not mean censorship; rather, it provides a structure within which free speech can operate without harm. The goal is not to stifle dialogue but to create a safe and equitable digital environment for all users.
#
# Conclusion
#
# As social media platforms continue to entwine themselves with societal functions, the call for government regulation becomes increasingly urgent. Regulation is not about stifling innovation or limiting free speech; it is about fostering accountability, protecting individual rights, and preserving democratic integrity. By implementing sensible regulations, governments can guide social media platforms towards responsible operation, ensuring they serve as tools that enhance, rather than harm, societal progress. The digital frontier is vast and ever-evolving, but with thoughtful oversight, it can be navigated to benefit both individuals and the collective global community.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a balanced, constructive look at your draft, organized around structure, clarity, argument strength, and style:
#
# 1. Structure
# • Clear sectional layout: You’ve neatly divided the essay into an introduction, three main arguments, opposition, and conclusion. This makes it easy to follow.
# • Transitional flow: At times the jump from one section to the next feels abrupt. Consider brief transitional sentences (“Building on the need for accountability…,” “Equally important is how regulation affects democratic processes…”) to guide the reader.
# • Depth of development: Each section introduces a solid thesis, but some could benefit from subpoints or mini-headings (e.g., under “Protecting Users’ Rights,” you might have sub-sections on privacy and on free-speech concerns).
#
# 2. Clarity of Message
# • Strong central claim: Your thesis—that government regulation is both necessary and compatible with free expression—comes through clearly.
# • Precision and specificity: Phrases like “immense power” or “significant impact” are evocative, but concrete examples (a particular misinformation campaign, data-breach statistics, or a court ruling) would anchor your claims.
# • Avoiding generalities: When you say platforms “fail to adequately address harmful content,” you might specify the type of content or cite a study on moderation backlogs to sharpen the point.
#
# 3. Strength of Arguments
# • Accountability: The call for “ethical standards” is persuasive. To reinforce it, you could cite existing regulatory proposals (e.g., the EU’s Digital Services Act) or outcomes from self-regulatory bodies.
# • Users’ Rights: You rightly highlight privacy and algorithmic bias. Adding a brief case study—say, Cambridge Analytica for data misuse or a documented algorithmic amplification of extremist content—would make this more convincing.
# • Democratic Processes: Good identification of misinformation and foreign interference. You could strengthen it by noting specific electoral events where social media played a documented role (e.g., 2016 U.S. election, Brexit referendum).
# • Handling objections: You acknowledge concerns about innovation and censorship, and you distinguish “responsible regulation” from “authoritarian control.” You might anticipate a secondary objection—how to enforce standards internationally when platforms are global—and briefly suggest coordination mechanisms (multilateral treaties, cross-border regulatory bodies).
#
# 4. Writing Style
# • Tone: Your language is formal and balanced, suitable for a policy-oriented essay.
# • Sentence variety: Most sentences are similarly structured (intro phrase + claim + rationale). Introducing shorter, punchier sentences in key places (e.g., the thesis statement or conclusion) can increase impact.
# • Word choice: Watch for repetition (“regulation,” “platforms,” “government”)—vary with synonyms like “oversight,” “services,” or “public authorities” where appropriate.
# • Conciseness: A few sentences could be tightened. For instance, “Given their significant impact, a pertinent question arises: should social media platforms be regulated by the government?” could be shortened to “Given their impact on society, should governments regulate social media?”
#
# 5. Suggestions for Revision
# • Add concrete examples or data points in each main section to support your claims.
# • Smooth transitions between sections to improve the essay’s narrative flow.
# • Deepen the counterargument section by addressing enforcement challenges and international coordination.
# • Vary sentence length and structure to maintain reader engagement and emphasize key ideas.
# • Trim redundant phrases to sharpen your prose.
#
# Overall, your draft lays a solid foundation: you have a clear thesis, logical structure, and a fair engagement with opposing views. By grounding your arguments in specific examples, refining transitions, and tightening your style, you’ll move from a persuasive outline to a truly compelling essay.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction
#
# In today’s digital age, social media platforms have become integral to daily life, influencing how people communicate, acquire information, and engage with society. These platforms wield significant power, shaping public opinion, influencing elections, and sometimes sparking real-world actions. This influence raises an essential question: should governments regulate social media platforms? This essay argues that such regulation is necessary to ensure accountability, protect users' rights, and preserve democratic processes.
#
# The Need for Accountability
#
# Social media platforms like Facebook, Twitter, and Instagram have grown into powerful entities with substantial influence. Operating with minimal oversight, they often prioritize profits over users’ welfare, neglecting issues like misinformation, harmful content, and data privacy violations. Government regulation is essential to ensure these companies adhere to ethical standards. For instance, the European Union’s Digital Services Act provides a framework for transparency and accountability, obliging social media platforms to prioritize user safety and societal well-being. By mandating clear guidelines and oversight, governments can create a healthier digital environment.
#
# Protecting Users' Rights
#
# In the digital sphere, users' rights, including privacy and freedom of expression, are frequently compromised. Social media platforms commercialize personal data, often disregarding users' privacy concerns. Furthermore, their algorithms can inadvertently promote echo chambers and censor diverse viewpoints. Through comprehensive regulation, governments can protect these rights. The Cambridge Analytica scandal vividly illustrates the misuse of personal data, highlighting the need for robust data protection policies. By mandating transparency and empowering users with greater control over their online presence, regulations can balance privacy with free speech while preventing harm.
#
# Preserving Democratic Processes
#
# Social media’s role in political landscapes worldwide cannot be ignored. While these platforms provide a voice for marginalized groups, they also spread misinformation, fake news, and enable political manipulation. The unchecked dissemination of false information can undermine democratic processes and influence election outcomes. Government regulation is crucial in setting standards to mitigate these risks. For example, the spread of misinformation during the 2016 U.S. election underscores the need for robust fact-checking and measures to prevent foreign interference. By establishing oversight frameworks, governments can ensure that social media platforms act responsibly, contributing to informed and democratic political processes.
#
# Opposition to Regulation
#
# Critics argue that regulation could stifle innovation and infringe on free speech. However, it is vital to distinguish between responsible regulation and authoritarian control. Thoughtfully crafted regulations can balance protecting rights with fostering innovation. Regulation does not equate to censorship; instead, it provides a structure within which free speech can thrive without harm. Addressing another potential objection, international coordination is necessary since social media platforms operate globally. Multilateral treaties or cross-border regulatory bodies could help enforce standards internationally.
#
# Conclusion
#
# As social media platforms continue to intertwine with societal functions, the call for government regulation becomes increasingly urgent. Regulation is not about stifling innovation or limiting free speech; it is about fostering accountability, protecting individual rights, and preserving democratic integrity. By implementing sensible regulations, governments can guide social media towards responsible operation, ensuring these platforms bolster rather than hinder societal progress. The digital frontier is vast and ever-evolving, but with thoughtful oversight, it can be navigated to benefit individuals and the global community alike.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
